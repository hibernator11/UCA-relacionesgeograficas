# %% [markdown]
# ## Explorando las localizaciones geográficas

# %%
# !conda install -c conda-forge folium
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done

# %%
import requests
import pandas as pd
import json
import csv
from pandas.io.json import json_normalize  
import folium

# %%
from rdflib import Graph

# Create a Graph
g = Graph().parse("rdf/relaciones_uca.rdf")

# %%
print('##### edm:Place')

# Query the data in g using SPARQL
# This query returns the 'name' of all ``edm:Place`` instances
q = """
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX edm: <http://www.europeana.eu/schemas/edm/>
    PREFIX wgs: <http://www.w3.org/2003/01/geo/wgs84_pos#>

    SELECT distinct ?p ?lat ?long ?lbl ?wikidata ?geonames
    WHERE {
        # ?p rdf:type edm:Place .
        # ?p skos:prefLabel ?lbl .
        # ?p wgs:long ?long .
        # ?p wgs:lat ?lat .
        # ?p owl:sameAs ?wikidata . FILTER ( strstarts(str(?wikidata), "https://www.wikidata.org/wiki/") ).
        # ?p owl:sameAs ?geonames . FILTER ( strstarts(str(?geonames), "https://www.geonames.org/") )
    }
"""
# Out:
# ##### edm:Place

# %%
# Apply the query to the graph and iterate through results
#print(r['p'] + ' ' + r["lbl"] + ' ' + r["lat"] + ' ' + r["long"])  
    
mapa_circulos = folium.Map(location=[23,-102], tiles="OpenStreetMap", zoom_start=5)

for r in g.query(q):
    idwikidata = r['wikidata']
    lat = r['lat']
    lon = r['long']
    idgeonames = r['geonames']
    etiqueta = r['lbl']
    
    #total = df.loc[df['id_geonames'] == "http://sws.geonames.org/"+idgeonames+"/", ["total"]].values[0][0]
        
    texto_popup = "Registros publicados en <a href='" + idwikidata + "'>" + etiqueta + "</a>"

    folium.Circle(
      location=[lat, lon],
      popup=texto_popup,
      #radius=float(total)/10,
      color='crimson',
      fill=True,
      fill_color='crimson'
    ).add_to(mapa_circulos)

mapa_circulos
# Out:
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3892209 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3892209'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3892209'>Mexico (country)| Oaxaca (state)| Santa María Peñoles does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3892209'>Mexico (country)| Oaxaca (state)| Santa María Peñoles</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1021051 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1021051'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1021051'>Mexico (country)| Michoacán (state)| Pátzcuaro does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1021051'>Mexico (country)| Michoacán (state)| Pátzcuaro</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3892861 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3892861'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3892861'>Mexico (country)| Oaxaca (state)| Santa Cruz Mixtepec does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3892861'>Mexico (country)| Oaxaca (state)| Santa Cruz Mixtepec</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1748818 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1748818'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1748818'>Guatemala (country)| Suchitepéquez (state)| San Antonio Suchitepéquez does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1748818'>Guatemala (country)| Suchitepéquez (state)| San Antonio Suchitepéquez</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2401093 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2401093'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2401093'>| Guatemala (country)| Sacatepéquez (state)| San Bartolomé Milpas Altas does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2401093'>| Guatemala (country)| Sacatepéquez (state)| San Bartolomé Milpas Altas</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2608452 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2608452'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2608452'>| Guatemala (country)| Suchitepéquez (state)| San Francisco Zapotitlán does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2608452'>| Guatemala (country)| Suchitepéquez (state)| San Francisco Zapotitlán</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q168622 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q168622'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q168622'>Guatemala (country)| Sololá (state)| Santiago Atitlán does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q168622'>Guatemala (country)| Sololá (state)| Santiago Atitlán</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2402766 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2402766'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2402766'>| Guatemala (country)| Sololá (state)| San Andrés Semetabaj does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2402766'>| Guatemala (country)| Sololá (state)| San Andrés Semetabaj</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20284390 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20284390'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20284390'>| Mexico (country)| Oaxaca (state)| Santos Reyes Zochiquilazola does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20284390'>| Mexico (country)| Oaxaca (state)| Santos Reyes Zochiquilazola</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q10812443 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q10812443'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q10812443'>| Mexico (country)| Oaxaca (state)| San Juan Mixtepec does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q10812443'>| Mexico (country)| Oaxaca (state)| San Juan Mixtepec</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q617691 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q617691'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q617691'>| Mexico (country)| Oaxaca (state)| Putla Villa de Guerrero does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q617691'>| Mexico (country)| Oaxaca (state)| Putla Villa de Guerrero</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1465498 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1465498'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1465498'>Mexico (country)| Hidalgo (state)| Metztitlán does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1465498'>Mexico (country)| Hidalgo (state)| Metztitlán</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q629479 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q629479'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q629479'>Mexico (country)| Oaxaca (state)| Tehuantepec does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q629479'>Mexico (country)| Oaxaca (state)| Tehuantepec</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20294779 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20294779'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20294779'>Mexico (country)| Oaxaca (state)| San Pedro Teozacoalco does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20294779'>Mexico (country)| Oaxaca (state)| San Pedro Teozacoalco</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20294779 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20294779'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20294779'>Mexico (country)| Oaxaca (state)| San Pedro Teozacoalco does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20294779'>Mexico (country)| Oaxaca (state)| San Pedro Teozacoalco</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2918021 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2918021'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2918021'>| Mexico (country)| Jalisco (state)| Tuxcacuesco does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2918021'>| Mexico (country)| Jalisco (state)| Tuxcacuesco</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3311317 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3311317'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3311317'>| Mexico (country)| Jalisco (state)| Zapotitlán de Vadillo does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3311317'>| Mexico (country)| Jalisco (state)| Zapotitlán de Vadillo</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3311299 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3311299'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3311299'>Mexico (country)| Jalisco (state)| Cuautitlán de García Barragán does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3311299'>Mexico (country)| Jalisco (state)| Cuautitlán de García Barragán</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3887619 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3887619'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3887619'>| Mexico (country)| Puebla (state)| Tenampulco does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3887619'>| Mexico (country)| Puebla (state)| Tenampulco</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3887619 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3887619'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3887619'>Mexico (country)| Puebla (state)| Tenampulco does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3887619'>Mexico (country)| Puebla (state)| Tenampulco</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2732754 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2732754'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2732754'>Mexico (country)| Morelos (state)| Yecapixtla does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2732754'>Mexico (country)| Morelos (state)| Yecapixtla</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20287259 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20287259'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20287259'>Mexico (country)| Jalisco (state)| Teocaltiche does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q20287259'>Mexico (country)| Jalisco (state)| Teocaltiche</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q173270 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q173270'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q173270'>Mexico (country)| Veracruz (state)| Heroica Veracruz does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q173270'>Mexico (country)| Veracruz (state)| Heroica Veracruz</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3845429 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3845429'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3845429'>Mexico (country)| Hidalgo (state)| Epazoyucan does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q3845429'>Mexico (country)| Hidalgo (state)| Epazoyucan</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'>| Mexico (country)| Veracruz (state)| Tecolutla does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'>| Mexico (country)| Veracruz (state)| Tecolutla</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'>Mexico (country)| Veracruz (state)| Tecolutla does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'>Mexico (country)| Veracruz (state)| Tecolutla</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'>| Mexico (country)| Veracruz (state)| Tecolutla does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'>| Mexico (country)| Veracruz (state)| Tecolutla</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'>Mexico (country)| Veracruz (state)| Tecolutla does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q1675800'>Mexico (country)| Veracruz (state)| Tecolutla</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2842525 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2842525'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2842525'>Mexico (country)| Jalisco (state)| Ameca does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q2842525'>Mexico (country)| Jalisco (state)| Ameca</a> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q
does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q34828 does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q34828'> does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q34828'>Mexico (country)| Mexico (state)| Tequixquiac does not look like a valid URI, trying to serialize this will break.
# Registros publicados en <a href='https://www.wikidata.org/wiki/Q34828'>Mexico (country)| Mexico (state)| Tequixquiac</a> does not look like a valid URI, trying to serialize this will break.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_942739313ca53d5167150dafe271b280 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_942739313ca53d5167150dafe271b280&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_942739313ca53d5167150dafe271b280 = L.map(
#                 &quot;map_942739313ca53d5167150dafe271b280&quot;,
#                 {
#                     center: [23.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80c3961e76bfd150e3ba777771173a5c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_942739313ca53d5167150dafe271b280);
#
#
#             var circle_3289d3730f828a3b41dea7b0d320de9e = L.circle(
#                 [17.079163, -97.002235],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_942739313ca53d5167150dafe271b280);
#
#
#         var popup_ffea09cadba80dedf4b4dfadc2149fa0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_32eb647ba85a246c54de75638846fb5a = $(`&lt;div id=&quot;html_32eb647ba85a246c54de75638846fb5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Registros publicados en &lt;a href=&#x27;https://www.wikidata.org/wiki/Q3892209&#x27;&gt;Mexico (country)| Oaxaca (state)| Santa María Peñoles&lt;/a&gt;&lt;/div&gt;`)[0];
#             popup_ffea09cadba80dedf4b4dfadc2149fa0.setContent(html_32eb647ba85a246c54de75638846fb5a);
#
#
#         circle_3289d3730f828a3b41dea7b0d320de9e.bindPopup(popup_ffea09cadba80dedf4b4dfadc2149fa0)
#         ;
#
#
#
#
#             var circle_a1a4c0adfe97352ab4617445c77130a8 = L.circle(
#                 [19.513479, -101.60919],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_942739313ca53d5167150dafe271b280);
#
#
#         var popup_b7c45ad17cb30089d57ca49d5a6ab2f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ede89e75c0c686127ec1bf20cc87d9eb = $(`&lt;div id=&quot;html_ede89e75c0c686127ec1bf20cc87d9eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Registros publicados en &lt;a href=&#x27;https://www.wikidata.org/wiki/Q1021051&#x27;&gt;Mexico (country)| Michoacán (state)| Pátzcuaro&lt;/a&gt;&lt;/div&gt;`)[0];
#             popup_b7c45ad17cb30089d57ca49d5a6ab2f2.setContent(html_ede89e75c0c686127ec1bf20cc87d9eb);
#
#
#         circle_a1a4c0adfe97352ab4617445c77130a8.bindPopup(popup_b7c45ad17cb30089d57ca49d5a6ab2f2)
#         ;
#
#
#
#
#             var circle_d29bb6c9e8f76c6fb21352ae8f2024db = L.circle(
#                 [16.792501, -96.881645],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_942739313ca53d5167150dafe271b280);
#
#
#         var popup_7a7cb9d4993ca1fa7bb0f5796b661b4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_62b84f3b90d61c87936a42c55ed0cb10 = $(`&lt;div id=&quot;html_62b84f3b90d61c87936a42c55ed0cb10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Registros publicados en &lt;a href=&#x27;https://www.wikidata.org/wiki/Q3892861&#x27;&gt;Mexico (country)| Oaxaca (state)| Santa Cruz Mixtepec&lt;/a&gt;&lt;/div&gt;`)[0];
#             popup_7a7cb9d4993ca1fa7bb0f5796b661b4b.setContent(html_62b84f3b90d61c87936a42c55ed0cb10);
#
#
#         circle_d29bb6c9e8f76c6fb21352ae8f2024db.bindPopup(popup_7a7cb9d4993ca1fa7bb0f5796b661b4b)
#         ;
#
#
#
#
#             var circle_8cbc1e73e93511b43d31087d7150df09 = L.circle(
#                 [14.539595, -91.41645],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;col
